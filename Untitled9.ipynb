# %%
# !pip install ucimlrepo
from ucimlrepo import fetch_ucirepo
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# fetch dataset
heart_disease = fetch_ucirepo(id=45)

# data (as pandas dataframes)
X = heart_disease.data.features
y = heart_disease.data.targets

# metadata
print(heart_disease.metadata)

# variable information
print(heart_disease.variables)
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %%
df = pd.concat([X, y], axis=1)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num
# 0  0.0   6.0    0
# 1  3.0   3.0    2
# 2  2.0   7.0    1
# 3  0.0   3.0    0
# 4  0.0   3.0    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  num       303 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 33.3 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %%
df.dropna(inplace = True)
df.reset_index(drop=True, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       297 non-null    int64
#  1   sex       297 non-null    int64
#  2   cp        297 non-null    int64
#  3   trestbps  297 non-null    int64
#  4   chol      297 non-null    int64
#  5   fbs       297 non-null    int64
#  6   restecg   297 non-null    int64
#  7   thalach   297 non-null    int64
#  8   exang     297 non-null    int64
#  9   oldpeak   297 non-null    float64
#  10  slope     297 non-null    int64
#  11  ca        297 non-null    float64
#  12  thal      297 non-null    float64
#  13  num       297 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 32.6 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
categorical_features = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope','thal']
numerical_features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']
X = df.drop('num', axis=1)
y = df['num']

# %%
n_features = len(X.columns)
n_cols = 4
n_rows = int(np.ceil(n_features / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 8))
axes = axes.flatten()

for i, col in enumerate(X.columns):
    sns.histplot(X[col], kde=True, color='purple', ax=axes[i])
    axes[i].set_title(f"{col} Distribution")

for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
sns.pairplot(df, diag_kind='kde')
plt.show()

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, cmap="Purples", fmt=".2f", linewidths=0.5)

plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %%
n_features = len(numerical_features)
n_cols = 3
n_rows = int(np.ceil(n_features / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 8))
axes = axes.flatten()

for i, col in enumerate(numerical_features):
    sns.boxplot(y=X[col], color="purple", ax=axes[i])
    axes[i].set_title(f"{col} Boxplot")
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
y.value_counts()
# Out:
# num
# 0    160
# 1     54
# 2     35
# 3     35
# 4     13
# Name: count, dtype: int64

# %%
y = y.map(lambda x: 0 if x == 0 else 1)
y.value_counts()
# Out:
# num
# 0    160
# 1    137
# Name: count, dtype: int64

# %%
for col in categorical_features:
    print(f"{col}: {X[col].unique()}")
# Out:
# sex: [1 0]
# cp: [1 4 3 2]
# fbs: [1 0]
# restecg: [2 0 1]
# exang: [0 1]
# slope: [3 2 1]
# thal: [6. 3. 7.]

# %%
X_encoded = pd.get_dummies(X, columns=['cp', 'restecg', 'slope', 'thal'], drop_first=True)
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal
# 0  0.0   6.0
# 1  3.0   3.0
# 2  2.0   7.0
# 3  0.0   3.0
# 4  0.0   3.0

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

pca = PCA()
X_pca_full = pca.fit_transform(X_scaled)

explained_var = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(8,5))
plt.plot(range(1, len(explained_var)+1), explained_var, marker='o', linestyle='--', color='purple')
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA - Explained Variance")
plt.grid(True)
plt.show()

n_components = np.argmax(explained_var >= 0.90) + 1

pca_final = PCA(n_components=n_components)
X_pca = pca_final.fit_transform(X_scaled)


plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap="coolwarm", alpha=0.7)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA - First Two Components")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)
rf.fit(X_encoded, y)

# Feature importance scores
rf_importances = pd.Series(rf.feature_importances_, index=X_encoded.columns)
top_rf_features = rf_importances.sort_values(ascending=False).head(10).index

# Sort and plot top 15
plt.figure(figsize=(10,6))
rf_importances.sort_values(ascending=False).head(10).plot(kind='bar', color='purple')
plt.title("Top 10 Features - Random Forest Importance")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.show()

print(top_rf_features)
# Out:
# Index(['ca', 'thalach', 'oldpeak', 'cp_4', 'thal_7.0', 'age', 'chol',
#        'trestbps', 'exang', 'slope_2'],
#       dtype='object')

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=1000, solver="liblinear", random_state=42)

rfe = RFE(estimator=log_reg, n_features_to_select=10)
rfe.fit(X_scaled, y)


selected_features_rfe = X_encoded.columns[rfe.support_]

print("Selected by RFE:")
print(list(selected_features_rfe))
# Out:
# Selected by RFE:
# ['sex', 'trestbps', 'thalach', 'exang', 'oldpeak', 'ca', 'cp_2', 'cp_4', 'slope_2', 'thal_7.0']

# %%
from sklearn.feature_selection import chi2, SelectKBest

chi2_selector = SelectKBest(score_func=chi2, k=10)
chi2_selector.fit(X_encoded, y)

selected_features_chi2 = X_encoded.columns[chi2_selector.get_support()]
print("Selected by Chi-Square:", list(selected_features_chi2))
# Out:
# Selected by Chi-Square: ['age', 'chol', 'thalach', 'exang', 'oldpeak', 'ca', 'cp_3', 'cp_4', 'slope_2', 'thal_7.0']

# %%
final_features = set(top_rf_features) | set(selected_features_rfe) | set(selected_features_chi2)
print("Final Selected Features:", list(final_features))

X_selected = X_encoded[list(final_features)]
print("X_selected shape:", X_selected.shape)
# Out:
# Final Selected Features: ['cp_2', 'trestbps', 'thalach', 'sex', 'cp_4', 'age', 'ca', 'chol', 'cp_3', 'slope_2', 'exang', 'oldpeak', 'thal_7.0']
# X_selected shape: (297, 13)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

scaler = StandardScaler()
X_selected_scaled = scaler.fit_transform(X_selected)

X_train, X_test, y_train, y_test = train_test_split(
    X_selected_scaled, y, test_size=0.2, random_state=42, stratify=y
)

models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, solver="liblinear", random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "SVM": SVC(random_state=42)
}

plt.figure(figsize=(8,6))

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(f"\n--- {name} ---")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))

    if name != "SVM":
      y_proba = model.predict_proba(X_test)[:,1]
      fpr, tpr, _ = roc_curve(y_test, y_proba)
      auc = roc_auc_score(y_test, y_proba)

      plt.plot(fpr, tpr, label=f"{name} (AUC={auc:.2f})")

plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves - All Models")
plt.legend()
plt.show()
# Out:
# --- Logistic Regression ---
# Accuracy: 0.8333333333333334
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.85        32
#            1       0.88      0.75      0.81        28
#
#     accuracy                           0.83        60
#    macro avg       0.84      0.83      0.83        60
# weighted avg       0.84      0.83      0.83        60
#
#
# --- Decision Tree ---
# Accuracy: 0.75
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79        32
#            1       0.81      0.61      0.69        28
#
#     accuracy                           0.75        60
#    macro avg       0.76      0.74      0.74        60
# weighted avg       0.76      0.75      0.74        60
#
#
# --- Random Forest ---
# Accuracy: 0.8333333333333334
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85        32
# ...

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
from scipy.cluster.hierarchy import dendrogram, linkage
# !pip install kneed
from kneed import KneeLocator

wcss = []
K_range = range(1, 11)
for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_selected_scaled)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(8,5))
plt.plot(K_range, wcss, 'bo-')
plt.xlabel('Number of clusters K')
plt.ylabel('WCSS (Inertia)')
plt.title('Elbow Method for Optimal K')
plt.show()

kneedle = KneeLocator(K_range, wcss, curve='convex', direction='decreasing')
best_k_elbow = kneedle.knee
print(f"Best K from Elbow: {best_k_elbow}")


optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
kmeans_labels = kmeans.fit_predict(X_scaled)


linked = linkage(X_selected_scaled, method='ward')
plt.figure(figsize=(10, 5))
dendrogram(linked, truncate_mode='level', p=5)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# Agglomerative Clustering with same K
hier_labels = AgglomerativeClustering(n_clusters=optimal_k, linkage='ward').fit_predict(X_scaled)

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_selected_scaled)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], hue=kmeans_labels, palette='Set1', s=60)
plt.title('K-Means Clusters')

plt.subplot(1,2,2)
sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], hue=hier_labels, palette='Set2', s=60)
plt.title('Hierarchical Clusters')
plt.show()


ari_kmeans = adjusted_rand_score(y, kmeans_labels)
nmi_kmeans = normalized_mutual_info_score(y, kmeans_labels)

ari_hier = adjusted_rand_score(y, hier_labels)
nmi_hier = normalized_mutual_info_score(y, hier_labels)

print(f"K-Means: ARI={ari_kmeans:.3f}, NMI={nmi_kmeans:.3f}")
print(f"Hierarchical: ARI={ari_hier:.3f}, NMI={nmi_hier:.3f}")

# Optional: Cross-tabulation
print("\nK-Means vs Actual Disease:")
print(pd.crosstab(kmeans_labels, y))

print("\nHierarchical vs Actual Disease:")
print(pd.crosstab(hier_labels, y))
# Out:
# ...
# Best K from Elbow: 4
# K-Means: ARI=0.205, NMI=0.182
# Hierarchical: ARI=0.098, NMI=0.101
#
# K-Means vs Actual Disease:
# num     0   1
# row_0
# 0      70  17
# 1       6  12
# 2      59  15
# 3      25  93
#
# Hierarchical vs Actual Disease:
# num     0   1
# row_0
# 0      15  24
# 1      62  18
# 2      43  85
# 3      40  10

# %%
log_reg_params = {
    "C": [0.01, 0.1, 1, 10, 100],
    "penalty": ["l1", "l2"],
    "solver": ["liblinear"]
}
dt_params = {
    "max_depth": [None, 3, 5, 7, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "criterion": ["gini", "entropy"]
}
rf_params = {
    "n_estimators": [50, 100, 200],
    "max_depth": [None, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "bootstrap": [True, False]
}
svm_params = {
    "C": [0.1, 1, 10, 100],
    "kernel": ["linear", "rbf", "poly"],
    "gamma": ["scale", "auto"]
}

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

param_grids = {
    "Logistic Regression": log_reg_params,
    "Decision Tree": dt_params,
    "Random Forest": rf_params,
    "SVM": svm_params
}

best_models = {}

for name, model in models.items():
    print(f"\nTuning hyperparameters for {name}...")

    params = param_grids[name]

    if name in ["Logistic Regression", "Decision Tree", "Random Forest"]:
        search = GridSearchCV(model, params, cv=5, scoring="roc_auc", n_jobs=-1)
    else:
        search = RandomizedSearchCV(model, params, cv=5, scoring="roc_auc", n_iter=20, n_jobs=-1, random_state=42)

    search.fit(X_train, y_train)
    best_models[name] = search.best_estimator_

    print(f"Best params for {name}: {search.best_params_}")

plt.figure(figsize=(8,6))

for name, model in best_models.items():
    y_pred = model.predict(X_test)

    print(f"\n--- {name} (Optimized) ---")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))

    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(X_test)[:,1]
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        auc = roc_auc_score(y_test, y_proba)
        plt.plot(fpr, tpr, label=f"{name} (AUC={auc:.2f})")

plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves - Optimized Models")
plt.legend()
plt.show()
# Out:
# Tuning hyperparameters for Logistic Regression...
# Best params for Logistic Regression: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
#
# Tuning hyperparameters for Decision Tree...
# Best params for Decision Tree: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Tuning hyperparameters for Random Forest...
# Best params for Random Forest: {'bootstrap': True, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
#
# Tuning hyperparameters for SVM...
# Best params for SVM: {'kernel': 'linear', 'gamma': 'auto', 'C': 1}
#
# --- Logistic Regression (Optimized) ---
# Accuracy: 0.85
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        32
#            1       0.85      0.82      0.84        28
#
#     accuracy                           0.85        60
#    macro avg       0.85      0.85      0.85        60
# ...

# %%
import joblib

for name, model in best_models.items():
    filename = f"{name.replace(' ', '_')}_model.pkl"
    joblib.dump(model, filename)
    print(f"{name} saved as '{filename}'")

joblib.dump(scaler, "scaler.pkl")
print("Scaler saved as 'scaler.pkl'")
# Out:
# Logistic Regression saved as 'Logistic_Regression_model.pkl'
# Decision Tree saved as 'Decision_Tree_model.pkl'
# Random Forest saved as 'Random_Forest_model.pkl'
# SVM saved as 'SVM_model.pkl'
# Scaler saved as 'scaler.pkl'
